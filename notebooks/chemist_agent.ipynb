# %% [markdown]
# # Démo du Chemist Agent

# %%
import sys
import os
root = os.path.abspath("../")
if root not in sys.path:
    sys.path.append(root)

# %%
from peptide_pipeline.chemist.chemist_agent import ChemistAgent

# Initialisation de l'agent
agent = ChemistAgent()
print("ChemistAgent initialized successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from peptide_pipeline.chemist.chemist_agent import ChemistAgent
#       3 # Initialisation de l'agent
#       4 agent = ChemistAgent()
#
# File ~/multi-expert-peptide-pipeline/peptide_pipeline/chemist/__init__.py:2
#       1 from .base import BaseChemist
# ----> 2 from .chemist_agent import ChemistAgent
#       4 __all__ = ["BaseChemist", "ChemistAgent"]
#
# File ~/multi-expert-peptide-pipeline/peptide_pipeline/chemist/chemist_agent.py:3
#       1 from peptide_pipeline.chemist.base import BaseChemist
#       2 from typing import List, Dict, Any
# ----> 3 from peptide_pipeline.logger.logger import get_logger
#       4 import peptides as pp
#       5 from rdkit import Chem
#
# ModuleNotFoundError: No module named 'peptide_pipeline.logger'

# %%
# Test de validité
peptides_test = ["ACDEF", "INVALIDX", "XXAAH", "GHIKL", "A", "COH", 'CFFFFF']
agent.check_validity(peptides_test)

# %%
# Calcul des propriétés
props = agent.calculate_properties(["ACDEF", "GHIKL"])
print(props)
for p, prop in zip(["ACDEF", "GHIKL"], props):
    print(f"\nProperties for {p}:")
    for k, v in prop.items():
        print(f"  {k}: {v}")

# %%
# Filtrage
constraints = {
    "size": {"min": 3, "max": 10},
    "net_charge": {"min": -2.0, "max": 2.0}
}
filtered = agent.filter_peptides(["ACDE", "GGHK", "AHHGGGGAGGHHH"], constraints)
print(f"\nFiltered peptides: {filtered}")
